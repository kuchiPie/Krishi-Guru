# %% [markdown]
# <span style="color:orange; font-weight:bold">Note: To answer questions based on text documents, we recommend the procedure in <a href="https://github.com/openai/openai-cookbook/blob/main/examples/Question_answering_using_embeddings.ipynb">Question Answering using Embeddings</a>. Some of the code below may rely on <a href="https://github.com/openai/openai-cookbook/tree/main/transition_guides_for_deprecated_API_endpoints">deprecated API endpoints</a>.</span>

# %% [markdown]
# # 2. Creating a synthetic Q&A dataset
# We use [`davinci-instruct-beta-v3`](https://beta.openai.com/docs/engines/instruct-series-beta), a model specialized in following instructions, to create questions based on the given context. Then we also use [`davinci-instruct-beta-v3`](https://beta.openai.com/docs/engines/instruct-series-beta) to answer those questions, given the same context.
#
# This is expensive, and will also take a long time, as we call the davinci engine for each section. You can simply download the final dataset instead.
#
# We're using the dataset created using the [previous notebook](olympics-1-collect-data.ipynb)

# %% [markdown]
# ## 2.1 Read in the data, and create a context
# Create a context by concatenating the title, the heading and the content of that section

# %%
import pandas as pd
df = pd.read_csv('./data/data_splitted1.csv', index_col = [0])
df['context'] = df.title + "\n" + df.heading + "\n\nx" + df.content

df.head()
# Out:
#                        title                               heading  \
# 0                Adzuki bean                               Summary
# 1              Zinc toxicity       High levels of intake by humans
# 2  Pesticides in New Zealand                               2,4,5-T
# 3          Copper in biology  Hereditary copper metabolic diseases
# 4                     Tomato                              Diseases
#
#                                              content  tokens  \
# 0  Vigna angularis, also known as the azuki bean(...     148
# 1  Zinc has been used therapeutically at a dose o...     195
# 2  Manufacture of 2,4,5-Trichlorophenoxyacetic ac...      45
# 3  Several rare genetic diseases (Wilson disease,...     257
# 4  Tomato cultivars vary widely in their resistan...     247
#
#                                              context
# 0  Adzuki bean\nSummary\n\nxVigna angularis, also...
# 1  Zinc toxicity\nHigh levels of intake by humans...
# 2  Pesticides in New Zealand\n2,4,5-T\n\nxManufac...
# 3  Copper in biology\nHereditary copper metabolic...
# 4  Tomato\nDiseases\n\nxTomato cultivars vary wid...

# %% [markdown]
# ## 2.2 Create questions based on the context
# Use davinci-instruct to generate a number of plausible questions relating to the Wikipedia section contents.
#
# Note: We have used temperature=0, but it may be beneficial to experiment with a higher temperature to get a higher diversity of questions.
#
# <span style="color:orange; font-weight:bold">WARNING: This step will last a long time, and consume a lot of tokens, as it calls davinci-instruct for every section to generate a number of questions.</span>

# %%
import openai
openai.api_key = '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'

def get_questions(row):
    # nonlocal cnt
    # print(cnt)
    # cnt += 1
    context = row['context']
    print(str(row.name/len(df) * 100) + ' % completed. Current Index:', row.name )

    try:
        response = openai.Completion.create(
            engine="davinci-instruct-beta-v3",
            prompt=f"Write questions based on the text below\n\nText: {context}\n\nQuestions:\n1.",
            temperature=0,
            max_tokens=257,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
            stop=["\n\n"]
        )
        return response['choices'][0]['text']
    except:
        return ""



df['questions'] = df.apply(get_questions, axis = 1)
df['questions'] = "1." + df.questions
# print(df[['questions']].values[0][0])

# for i, context in enumerate(df['questions']):
#     questions = get_questions(context)
#     questions = "1." + questions
#     print(f"Row {i}: {questions}")
#     df.at[i, 'questions'] = questions
# Out:
# 0.0 % completed. Current Index: 0
# 0.030275507114744173 % completed. Current Index: 1
# 0.060551014229488345 % completed. Current Index: 2
# 0.09082652134423251 % completed. Current Index: 3
# 0.12110202845897669 % completed. Current Index: 4
# 0.15137753557372086 % completed. Current Index: 5
# 0.18165304268846502 % completed. Current Index: 6
# 0.2119285498032092 % completed. Current Index: 7
# 0.24220405691795338 % completed. Current Index: 8
# 0.2724795640326975 % completed. Current Index: 9
# 0.3027550711474417 % completed. Current Index: 10
# 0.3330305782621859 % completed. Current Index: 11
# 0.36330608537693004 % completed. Current Index: 12
# 0.39358159249167424 % completed. Current Index: 13
# 0.4238570996064184 % completed. Current Index: 14
# 0.4541326067211626 % completed. Current Index: 15
# 0.48440811383590676 % completed. Current Index: 16
# 0.5146836209506509 % completed. Current Index: 17
# 0.544959128065395 % completed. Current Index: 18
# 0.5752346351801393 % completed. Current Index: 19
# 0.6055101422948834 % completed. Current Index: 20
# 0.6357856494096277 % completed. Current Index: 21
# 0.6660611565243718 % completed. Current Index: 22
# 0.696336663639116 % completed. Current Index: 23
# 0.7266121707538601 % completed. Current Index: 24
# 0.7568876778686043 % completed. Current Index: 25
# 0.7871631849833485 % completed. Current Index: 26
# 0.8174386920980926 % completed. Current Index: 27
# 0.8477141992128367 % completed. Current Index: 28
# 0.877989706327581 % completed. Current Index: 29
# 0.9082652134423252 % completed. Current Index: 30
# 0.9385407205570693 % completed. Current Index: 31
# 0.9688162276718135 % completed. Current Index: 32
# 0.9990917347865577 % completed. Current Index: 33
# 1.0293672419013018 % completed. Current Index: 34
# 1.0596427490160458 % completed. Current Index: 35
# 1.08991825613079 % completed. Current Index: 36
# 1.1201937632455343 % completed. Current Index: 37
# 1.1504692703602786 % completed. Current Index: 38
# 1.1807447774750226 % completed. Current Index: 39
# 1.2110202845897668 % completed. Current Index: 40
# 1.241295791704511 % completed. Current Index: 41
# 1.2715712988192553 % completed. Current Index: 42
# 1.3018468059339994 % completed. Current Index: 43
# 1.3321223130487436 % completed. Current Index: 44
# 1.3623978201634876 % completed. Current Index: 45
# 1.392673327278232 % completed. Current Index: 46
# 1.4229488343929761 % completed. Current Index: 47
# 1.4532243415077202 % completed. Current Index: 48
# 1.4834998486224644 % completed. Current Index: 49
# 1.5137753557372087 % completed. Current Index: 50
# 1.544050862851953 % completed. Current Index: 51
# 1.574326369966697 % completed. Current Index: 52
# 1.6046018770814412 % completed. Current Index: 53
# 1.6348773841961852 % completed. Current Index: 54
# 1.6651528913109295 % completed. Current Index: 55
# 1.6954283984256735 % completed. Current Index: 56
# 1.725703905540418 % completed. Current Index: 57
# 1.755979412655162 % completed. Current Index: 58
# 1.786254919769906 % completed. Current Index: 59
# 1.8165304268846505 % completed. Current Index: 60
# 1.8468059339993945 % completed. Current Index: 61
# 1.8770814411141385 % completed. Current Index: 62
# 1.9073569482288828 % completed. Current Index: 63
# 1.937632455343627 % completed. Current Index: 64
# 1.9679079624583713 % completed. Current Index: 65
# 1.9981834695731153 % completed. Current Index: 66
# 2.0284589766878596 % completed. Current Index: 67
# 2.0587344838026036 % completed. Current Index: 68
# 2.0890099909173476 % completed. Current Index: 69
# 2.1192854980320917 % completed. Current Index: 70
# 2.149561005146836 % completed. Current Index: 71
# 2.17983651226158 % completed. Current Index: 72
# 2.2101120193763246 % completed. Current Index: 73
# 2.2403875264910686 % completed. Current Index: 74
# 2.2706630336058127 % completed. Current Index: 75
# 2.300938540720557 % completed. Current Index: 76
# 2.331214047835301 % completed. Current Index: 77
# 2.361489554950045 % completed. Current Index: 78
# 2.3917650620647897 % completed. Current Index: 79
# 2.4220405691795337 % completed. Current Index: 80
# 2.452316076294278 % completed. Current Index: 81
# 2.482591583409022 % completed. Current Index: 82
# 2.5128670905237662 % completed. Current Index: 83
# 2.5431425976385107 % completed. Current Index: 84
# 2.5734181047532547 % completed. Current Index: 85
# 2.6036936118679987 % completed. Current Index: 86
# 2.633969118982743 % completed. Current Index: 87
# 2.6642446260974872 % completed. Current Index: 88
# 2.6945201332122313 % completed. Current Index: 89
# 2.7247956403269753 % completed. Current Index: 90
# 2.7550711474417193 % completed. Current Index: 91
# 2.785346654556464 % completed. Current Index: 92
# 2.815622161671208 % completed. Current Index: 93
# 2.8458976687859523 % completed. Current Index: 94
# 2.8761731759006963 % completed. Current Index: 95
# 2.9064486830154403 % completed. Current Index: 96
# 2.936724190130185 % completed. Current Index: 97
# 2.966999697244929 % completed. Current Index: 98
# 2.997275204359673 % completed. Current Index: 99
# 3.0275507114744173 % completed. Current Index: 100
# 3.0578262185891614 % completed. Current Index: 101
# 3.088101725703906 % completed. Current Index: 102
# 3.11837723281865 % completed. Current Index: 103
# 3.148652739933394 % completed. Current Index: 104
# 3.178928247048138 % completed. Current Index: 105
# 3.2092037541628824 % completed. Current Index: 106
# 3.2394792612776264 % completed. Current Index: 107
# 3.2697547683923704 % completed. Current Index: 108
# 3.3000302755071145 % completed. Current Index: 109
# 3.330305782621859 % completed. Current Index: 110
# 3.3605812897366025 % completed. Current Index: 111
# 3.390856796851347 % completed. Current Index: 112
# 3.4211323039660915 % completed. Current Index: 113
# 3.451407811080836 % completed. Current Index: 114
# 3.4816833181955795 % completed. Current Index: 115
# 3.511958825310324 % completed. Current Index: 116
# 3.5422343324250685 % completed. Current Index: 117
# 3.572509839539812 % completed. Current Index: 118
# 3.6027853466545565 % completed. Current Index: 119
# 3.633060853769301 % completed. Current Index: 120
# 3.6633363608840446 % completed. Current Index: 121
# 3.693611867998789 % completed. Current Index: 122
# 3.7238873751135335 % completed. Current Index: 123
# 3.754162882228277 % completed. Current Index: 124
# 3.7844383893430216 % completed. Current Index: 125
# 3.8147138964577656 % completed. Current Index: 126
# 3.84498940357251 % completed. Current Index: 127
# 3.875264910687254 % completed. Current Index: 128
# 3.905540417801998 % completed. Current Index: 129
# 3.9358159249167426 % completed. Current Index: 130
# 3.966091432031486 % completed. Current Index: 131
# 3.9963669391462306 % completed. Current Index: 132
# 4.026642446260976 % completed. Current Index: 133
# 4.056917953375719 % completed. Current Index: 134
# 4.087193460490464 % completed. Current Index: 135
# 4.117468967605207 % completed. Current Index: 136
# 4.147744474719952 % completed. Current Index: 137
# 4.178019981834695 % completed. Current Index: 138
# 4.20829548894944 % completed. Current Index: 139
# 4.238570996064183 % completed. Current Index: 140
# 4.268846503178928 % completed. Current Index: 141
# 4.299122010293672 % completed. Current Index: 142
# 4.329397517408417 % completed. Current Index: 143
# 4.35967302452316 % completed. Current Index: 144
# 4.389948531637905 % completed. Current Index: 145
# 4.420224038752649 % completed. Current Index: 146
# 4.450499545867393 % completed. Current Index: 147
# 4.480775052982137 % completed. Current Index: 148
# 4.511050560096882 % completed. Current Index: 149
# 4.541326067211625 % completed. Current Index: 150
# 4.57160157432637 % completed. Current Index: 151
# 4.601877081441114 % completed. Current Index: 152
# 4.632152588555858 % completed. Current Index: 153
# 4.662428095670602 % completed. Current Index: 154
# 4.692703602785347 % completed. Current Index: 155
# 4.72297910990009 % completed. Current Index: 156
# 4.753254617014835 % completed. Current Index: 157
# 4.783530124129579 % completed. Current Index: 158
# 4.813805631244324 % completed. Current Index: 159
# 4.844081138359067 % completed. Current Index: 160
# 4.874356645473812 % completed. Current Index: 161
# 4.904632152588556 % completed. Current Index: 162
# 4.9349076597033 % completed. Current Index: 163
# 4.965183166818044 % completed. Current Index: 164
# 4.995458673932789 % completed. Current Index: 165
# 5.0257341810475324 % completed. Current Index: 166
# 5.056009688162277 % completed. Current Index: 167
# 5.086285195277021 % completed. Current Index: 168
# 5.116560702391765 % completed. Current Index: 169
# 5.146836209506509 % completed. Current Index: 170
# 5.177111716621254 % completed. Current Index: 171
# 5.2073872237359975 % completed. Current Index: 172
# 5.237662730850742 % completed. Current Index: 173
# 5.267938237965486 % completed. Current Index: 174
# 5.29821374508023 % completed. Current Index: 175
# 5.3284892521949745 % completed. Current Index: 176
# 5.358764759309718 % completed. Current Index: 177
# 5.3890402664244625 % completed. Current Index: 178
# 5.419315773539206 % completed. Current Index: 179
# 5.449591280653951 % completed. Current Index: 180
# 5.479866787768695 % completed. Current Index: 181
# 5.510142294883439 % completed. Current Index: 182
# 5.540417801998183 % completed. Current Index: 183
# 5.570693309112928 % completed. Current Index: 184
# 5.600968816227671 % completed. Current Index: 185
# 5.631244323342416 % completed. Current Index: 186
# 5.66151983045716 % completed. Current Index: 187
# 5.691795337571905 % completed. Current Index: 188
# 5.722070844686648 % completed. Current Index: 189
# 5.752346351801393 % completed. Current Index: 190
# 5.782621858916137 % completed. Current Index: 191
# 5.812897366030881 % completed. Current Index: 192
# 5.843172873145625 % completed. Current Index: 193
# 5.87344838026037 % completed. Current Index: 194
# 5.903723887375113 % completed. Current Index: 195
# 5.933999394489858 % completed. Current Index: 196
# 5.964274901604602 % completed. Current Index: 197
# 5.994550408719346 % completed. Current Index: 198
# 6.02482591583409 % completed. Current Index: 199
# 6.055101422948835 % completed. Current Index: 200
# 6.085376930063579 % completed. Current Index: 201
# 6.115652437178323 % completed. Current Index: 202
# 6.145927944293067 % completed. Current Index: 203
# 6.176203451407812 % completed. Current Index: 204
# 6.206478958522555 % completed. Current Index: 205
# 6.2367544656373 % completed. Current Index: 206
# 6.267029972752043 % completed. Current Index: 207
# 6.297305479866788 % completed. Current Index: 208
# 6.327580986981532 % completed. Current Index: 209
# 6.357856494096276 % completed. Current Index: 210
# 6.38813200121102 % completed. Current Index: 211
# 6.418407508325765 % completed. Current Index: 212
# 6.448683015440508 % completed. Current Index: 213
# 6.478958522555253 % completed. Current Index: 214
# 6.509234029669997 % completed. Current Index: 215
# 6.539509536784741 % completed. Current Index: 216
# 6.569785043899485 % completed. Current Index: 217
# 6.600060551014229 % completed. Current Index: 218
# 6.630336058128973 % completed. Current Index: 219
# 6.660611565243718 % completed. Current Index: 220
# 6.6908870723584615 % completed. Current Index: 221
# 6.721162579473205 % completed. Current Index: 222
# 6.75143808658795 % completed. Current Index: 223
# 6.781713593702694 % completed. Current Index: 224
# 6.811989100817439 % completed. Current Index: 225
# 6.842264607932183 % completed. Current Index: 226
# 6.8725401150469265 % completed. Current Index: 227
# 6.902815622161672 % completed. Current Index: 228
# 6.9330911292764155 % completed. Current Index: 229
# 6.963366636391159 % completed. Current Index: 230
# 6.993642143505904 % completed. Current Index: 231
# 7.023917650620648 % completed. Current Index: 232
# 7.054193157735392 % completed. Current Index: 233
# 7.084468664850137 % completed. Current Index: 234
# 7.1147441719648805 % completed. Current Index: 235
# 7.145019679079624 % completed. Current Index: 236
# 7.1752951861943695 % completed. Current Index: 237
# 7.205570693309113 % completed. Current Index: 238
# 7.235846200423857 % completed. Current Index: 239
# 7.266121707538602 % completed. Current Index: 240
# 7.296397214653346 % completed. Current Index: 241
# 7.326672721768089 % completed. Current Index: 242
# 7.3569482288828345 % completed. Current Index: 243
# 7.387223735997578 % completed. Current Index: 244
# 7.417499243112322 % completed. Current Index: 245
# 7.447774750227067 % completed. Current Index: 246
# 7.478050257341811 % completed. Current Index: 247
# 7.508325764456554 % completed. Current Index: 248
# 7.538601271571299 % completed. Current Index: 249
# 7.568876778686043 % completed. Current Index: 250
# 7.599152285800787 % completed. Current Index: 251
# 7.629427792915531 % completed. Current Index: 252
# 7.659703300030276 % completed. Current Index: 253
# 7.68997880714502 % completed. Current Index: 254
# 7.720254314259764 % completed. Current Index: 255
# 7.750529821374508 % completed. Current Index: 256
# 7.780805328489253 % completed. Current Index: 257
# 7.811080835603996 % completed. Current Index: 258
# 7.84135634271874 % completed. Current Index: 259
# 7.871631849833485 % completed. Current Index: 260
# 7.901907356948229 % completed. Current Index: 261
# 7.932182864062972 % completed. Current Index: 262
# 7.962458371177718 % completed. Current Index: 263
# 7.992733878292461 % completed. Current Index: 264
# 8.023009385407205 % completed. Current Index: 265
# 8.053284892521951 % completed. Current Index: 266
# 8.083560399636694 % completed. Current Index: 267
# 8.113835906751438 % completed. Current Index: 268
# 8.144111413866183 % completed. Current Index: 269
# 8.174386920980927 % completed. Current Index: 270
# 8.20466242809567 % completed. Current Index: 271
# 8.234937935210414 % completed. Current Index: 272
# 8.265213442325159 % completed. Current Index: 273
# 8.295488949439903 % completed. Current Index: 274
# 8.325764456554648 % completed. Current Index: 275
# 8.35603996366939 % completed. Current Index: 276
# 8.386315470784135 % completed. Current Index: 277
# 8.41659097789888 % completed. Current Index: 278
# 8.446866485013624 % completed. Current Index: 279
# 8.477141992128367 % completed. Current Index: 280
# 8.507417499243113 % completed. Current Index: 281
# 8.537693006357856 % completed. Current Index: 282
# 8.567968513472602 % completed. Current Index: 283
# 8.598244020587344 % completed. Current Index: 284
# 8.628519527702089 % completed. Current Index: 285
# 8.658795034816833 % completed. Current Index: 286
# 8.689070541931578 % completed. Current Index: 287
# 8.71934604904632 % completed. Current Index: 288
# 8.749621556161067 % completed. Current Index: 289
# 8.77989706327581 % completed. Current Index: 290
# 8.810172570390554 % completed. Current Index: 291
# 8.840448077505298 % completed. Current Index: 292
# 8.870723584620043 % completed. Current Index: 293
# 8.900999091734786 % completed. Current Index: 294
# 8.931274598849532 % completed. Current Index: 295
# 8.961550105964275 % completed. Current Index: 296
# 8.991825613079019 % completed. Current Index: 297
# 9.022101120193764 % completed. Current Index: 298
# 9.052376627308508 % completed. Current Index: 299
# 9.08265213442325 % completed. Current Index: 300
# 9.112927641537997 % completed. Current Index: 301
# 9.14320314865274 % completed. Current Index: 302
# 9.173478655767484 % completed. Current Index: 303
# 9.203754162882229 % completed. Current Index: 304
# 9.234029669996973 % completed. Current Index: 305
# 9.264305177111716 % completed. Current Index: 306
# 9.29458068422646 % completed. Current Index: 307
# 9.324856191341205 % completed. Current Index: 308
# 9.35513169845595 % completed. Current Index: 309
# 9.385407205570694 % completed. Current Index: 310
# 9.415682712685438 % completed. Current Index: 311
# 9.44595821980018 % completed. Current Index: 312
# 9.476233726914925 % completed. Current Index: 313
# 9.50650923402967 % completed. Current Index: 314
# 9.536784741144414 % completed. Current Index: 315
# 9.567060248259159 % completed. Current Index: 316
# 9.597335755373901 % completed. Current Index: 317
# 9.627611262488648 % completed. Current Index: 318
# 9.65788676960339 % completed. Current Index: 319
# 9.688162276718135 % completed. Current Index: 320
# 9.71843778383288 % completed. Current Index: 321
# 9.748713290947624 % completed. Current Index: 322
# 9.778988798062366 % completed. Current Index: 323
# 9.809264305177113 % completed. Current Index: 324
# 9.839539812291855 % completed. Current Index: 325
# 9.8698153194066 % completed. Current Index: 326
# 9.900090826521344 % completed. Current Index: 327
# 9.930366333636089 % completed. Current Index: 328
# 9.960641840750831 % completed. Current Index: 329
# 9.990917347865578 % completed. Current Index: 330
# 10.02119285498032 % completed. Current Index: 331
# 10.051468362095065 % completed. Current Index: 332
# 10.08174386920981 % completed. Current Index: 333
# 10.112019376324554 % completed. Current Index: 334
# 10.142294883439297 % completed. Current Index: 335
# 10.172570390554043 % completed. Current Index: 336
# 10.202845897668785 % completed. Current Index: 337
# 10.23312140478353 % completed. Current Index: 338
# 10.263396911898274 % completed. Current Index: 339
# 10.293672419013019 % completed. Current Index: 340
# 10.323947926127762 % completed. Current Index: 341
# 10.354223433242508 % completed. Current Index: 342
# 10.38449894035725 % completed. Current Index: 343
# 10.414774447471995 % completed. Current Index: 344
# 10.44504995458674 % completed. Current Index: 345
# 10.475325461701484 % completed. Current Index: 346
# 10.505600968816228 % completed. Current Index: 347
# 10.535876475930973 % completed. Current Index: 348
# 10.566151983045716 % completed. Current Index: 349
# 10.59642749016046 % completed. Current Index: 350
# 10.626702997275205 % completed. Current Index: 351
# 10.656978504389949 % completed. Current Index: 352
# 10.687254011504693 % completed. Current Index: 353
# 10.717529518619436 % completed. Current Index: 354
# 10.74780502573418 % completed. Current Index: 355
# 10.778080532848925 % completed. Current Index: 356
# 10.80835603996367 % completed. Current Index: 357
# 10.838631547078412 % completed. Current Index: 358
# 10.868907054193159 % completed. Current Index: 359
# 10.899182561307901 % completed. Current Index: 360
# 10.929458068422646 % completed. Current Index: 361
# 10.95973357553739 % completed. Current Index: 362
# 10.990009082652135 % completed. Current Index: 363
# 11.020284589766877 % completed. Current Index: 364
# 11.050560096881624 % completed. Current Index: 365
# 11.080835603996366 % completed. Current Index: 366
# 11.11111111111111 % completed. Current Index: 367
# 11.141386618225855 % completed. Current Index: 368
# 11.1716621253406 % completed. Current Index: 369
# 11.201937632455342 % completed. Current Index: 370
# 11.232213139570089 % completed. Current Index: 371
# 11.262488646684831 % completed. Current Index: 372
# 11.292764153799578 % completed. Current Index: 373
# 11.32303966091432 % completed. Current Index: 374
# 11.353315168029065 % completed. Current Index: 375
# 11.38359067514381 % completed. Current Index: 376
# 11.413866182258554 % completed. Current Index: 377
# 11.444141689373296 % completed. Current Index: 378
# 11.474417196488043 % completed. Current Index: 379
# 11.504692703602785 % completed. Current Index: 380
# 11.53496821071753 % completed. Current Index: 381
# 11.565243717832274 % completed. Current Index: 382
# 11.595519224947019 % completed. Current Index: 383
# 11.625794732061761 % completed. Current Index: 384
# 11.656070239176506 % completed. Current Index: 385
# 11.68634574629125 % completed. Current Index: 386
# 11.716621253405995 % completed. Current Index: 387
# 11.74689676052074 % completed. Current Index: 388
# 11.777172267635482 % completed. Current Index: 389
# 11.807447774750226 % completed. Current Index: 390
# 11.837723281864971 % completed. Current Index: 391
# 11.867998788979715 % completed. Current Index: 392
# 11.89827429609446 % completed. Current Index: 393
# 11.928549803209204 % completed. Current Index: 394
# 11.958825310323947 % completed. Current Index: 395
# 11.989100817438691 % completed. Current Index: 396
# 12.019376324553436 % completed. Current Index: 397
# 12.04965183166818 % completed. Current Index: 398
# 12.079927338782923 % completed. Current Index: 399
# 12.11020284589767 % completed. Current Index: 400
# 12.140478353012412 % completed. Current Index: 401
# 12.170753860127158 % completed. Current Index: 402
# 12.201029367241901 % completed. Current Index: 403
# 12.231304874356645 % completed. Current Index: 404
# 12.26158038147139 % completed. Current Index: 405
# 12.291855888586134 % completed. Current Index: 406
# 12.322131395700877 % completed. Current Index: 407
# 12.352406902815623 % completed. Current Index: 408
# 12.382682409930366 % completed. Current Index: 409
# 12.41295791704511 % completed. Current Index: 410
# 12.443233424159855 % completed. Current Index: 411
# 12.4735089312746 % completed. Current Index: 412
# 12.503784438389342 % completed. Current Index: 413
# 12.534059945504087 % completed. Current Index: 414
# 12.56433545261883 % completed. Current Index: 415
# 12.594610959733576 % completed. Current Index: 416
# 12.62488646684832 % completed. Current Index: 417
# 12.655161973963065 % completed. Current Index: 418
# 12.685437481077807 % completed. Current Index: 419
# 12.715712988192552 % completed. Current Index: 420
# 12.745988495307298 % completed. Current Index: 421
# 12.77626400242204 % completed. Current Index: 422
# 12.806539509536785 % completed. Current Index: 423
# 12.83681501665153 % completed. Current Index: 424
# 12.867090523766272 % completed. Current Index: 425
# 12.897366030881017 % completed. Current Index: 426
# 12.927641537995763 % completed. Current Index: 427
# 12.957917045110506 % completed. Current Index: 428
# 12.98819255222525 % completed. Current Index: 429
# 13.018468059339995 % completed. Current Index: 430
# 13.048743566454737 % completed. Current Index: 431
# 13.079019073569482 % completed. Current Index: 432
# 13.109294580684228 % completed. Current Index: 433
# 13.13957008779897 % completed. Current Index: 434
# 13.169845594913715 % completed. Current Index: 435
# 13.200121102028458 % completed. Current Index: 436
# 13.230396609143202 % completed. Current Index: 437
# 13.260672116257947 % completed. Current Index: 438
# 13.290947623372693 % completed. Current Index: 439
# 13.321223130487436 % completed. Current Index: 440
# 13.35149863760218 % completed. Current Index: 441
# 13.381774144716923 % completed. Current Index: 442
# 13.412049651831667 % completed. Current Index: 443
# 13.44232515894641 % completed. Current Index: 444
# 13.472600666061158 % completed. Current Index: 445
# 13.5028761731759 % completed. Current Index: 446
# 13.533151680290645 % completed. Current Index: 447
# 13.563427187405388 % completed. Current Index: 448
# 13.593702694520132 % completed. Current Index: 449
# 13.623978201634879 % completed. Current Index: 450
# 13.654253708749623 % completed. Current Index: 451
# 13.684529215864366 % completed. Current Index: 452
# 13.71480472297911 % completed. Current Index: 453
# 13.745080230093853 % completed. Current Index: 454
# 13.775355737208598 % completed. Current Index: 455
# 13.805631244323344 % completed. Current Index: 456
# 13.835906751438088 % completed. Current Index: 457
# 13.866182258552831 % completed. Current Index: 458
# 13.896457765667575 % completed. Current Index: 459
# 13.926733272782318 % completed. Current Index: 460
# 13.957008779897063 % completed. Current Index: 461
# 13.987284287011809 % completed. Current Index: 462
# 14.017559794126552 % completed. Current Index: 463
# 14.047835301241296 % completed. Current Index: 464
# 14.07811080835604 % completed. Current Index: 465
# 14.108386315470783 % completed. Current Index: 466
# 14.138661822585528 % completed. Current Index: 467
# 14.168937329700274 % completed. Current Index: 468
# 14.199212836815017 % completed. Current Index: 469
# 14.229488343929761 % completed. Current Index: 470
# 14.259763851044504 % completed. Current Index: 471
# 14.290039358159248 % completed. Current Index: 472
# 14.320314865273993 % completed. Current Index: 473
# 14.350590372388739 % completed. Current Index: 474
# 14.380865879503482 % completed. Current Index: 475
# 14.411141386618226 % completed. Current Index: 476
# 14.441416893732969 % completed. Current Index: 477
# 14.471692400847713 % completed. Current Index: 478
# 14.50196790796246 % completed. Current Index: 479
# 14.532243415077204 % completed. Current Index: 480
# 14.562518922191947 % completed. Current Index: 481
# 14.592794429306691 % completed. Current Index: 482
# 14.623069936421434 % completed. Current Index: 483
# 14.653345443536178 % completed. Current Index: 484
# 14.683620950650925 % completed. Current Index: 485
# 14.713896457765669 % completed. Current Index: 486
# 14.744171964880412 % completed. Current Index: 487
# 14.774447471995156 % completed. Current Index: 488
# 14.804722979109899 % completed. Current Index: 489
# 14.834998486224643 % completed. Current Index: 490
# 14.86527399333939 % completed. Current Index: 491
# 14.895549500454134 % completed. Current Index: 492
# 14.925825007568877 % completed. Current Index: 493
# 14.956100514683621 % completed. Current Index: 494
# 14.986376021798364 % completed. Current Index: 495
# 15.016651528913108 % completed. Current Index: 496
# 15.046927036027855 % completed. Current Index: 497
# 15.077202543142597 % completed. Current Index: 498
# 15.107478050257342 % completed. Current Index: 499
# 15.137753557372086 % completed. Current Index: 500
# 15.168029064486829 % completed. Current Index: 501
# 15.198304571601573 % completed. Current Index: 502
# 15.22858007871632 % completed. Current Index: 503
# 15.258855585831062 % completed. Current Index: 504
# 15.289131092945807 % completed. Current Index: 505
# 15.319406600060551 % completed. Current Index: 506
# 15.349682107175294 % completed. Current Index: 507
# 15.37995761429004 % completed. Current Index: 508
# 15.410233121404785 % completed. Current Index: 509
# 15.440508628519527 % completed. Current Index: 510
# 15.470784135634272 % completed. Current Index: 511
# 15.501059642749016 % completed. Current Index: 512
# 15.531335149863759 % completed. Current Index: 513
# 15.561610656978505 % completed. Current Index: 514
# 15.59188616409325 % completed. Current Index: 515
# 15.622161671207992 % completed. Current Index: 516
# 15.652437178322737 % completed. Current Index: 517
# 15.68271268543748 % completed. Current Index: 518
# 15.712988192552224 % completed. Current Index: 519
# 15.74326369966697 % completed. Current Index: 520
# 15.773539206781715 % completed. Current Index: 521
# 15.803814713896458 % completed. Current Index: 522
# 15.834090221011202 % completed. Current Index: 523
# 15.864365728125945 % completed. Current Index: 524
# 15.89464123524069 % completed. Current Index: 525
# 15.924916742355435 % completed. Current Index: 526
# 15.95519224947018 % completed. Current Index: 527
# 15.985467756584923 % completed. Current Index: 528
# 16.015743263699665 % completed. Current Index: 529
# 16.04601877081441 % completed. Current Index: 530
# 16.076294277929154 % completed. Current Index: 531
# 16.106569785043902 % completed. Current Index: 532
# 16.136845292158643 % completed. Current Index: 533
# 16.167120799273388 % completed. Current Index: 534
# 16.197396306388132 % completed. Current Index: 535
# 16.227671813502877 % completed. Current Index: 536
# 16.25794732061762 % completed. Current Index: 537
# 16.288222827732366 % completed. Current Index: 538
# 16.31849833484711 % completed. Current Index: 539
# 16.348773841961854 % completed. Current Index: 540
# 16.379049349076595 % completed. Current Index: 541
# 16.40932485619134 % completed. Current Index: 542
# 16.439600363306088 % completed. Current Index: 543
# 16.46987587042083 % completed. Current Index: 544
# 16.500151377535573 % completed. Current Index: 545
# 16.530426884650318 % completed. Current Index: 546
# 16.560702391765062 % completed. Current Index: 547
# 16.590977898879807 % completed. Current Index: 548
# 16.62125340599455 % completed. Current Index: 549
# 16.651528913109296 % completed. Current Index: 550
# 16.68180442022404 % completed. Current Index: 551
# 16.71207992733878 % completed. Current Index: 552
# 16.742355434453525 % completed. Current Index: 553
# 16.77263094156827 % completed. Current Index: 554
# 16.802906448683018 % completed. Current Index: 555
# 16.83318195579776 % completed. Current Index: 556
# 16.863457462912503 % completed. Current Index: 557
# 16.893732970027248 % completed. Current Index: 558
# 16.924008477141992 % completed. Current Index: 559
# 16.954283984256733 % completed. Current Index: 560
# 16.98455949137148 % completed. Current Index: 561
# 17.014834998486226 % completed. Current Index: 562
# 17.04511050560097 % completed. Current Index: 563
# 17.07538601271571 % completed. Current Index: 564
# 17.105661519830456 % completed. Current Index: 565
# 17.135937026945204 % completed. Current Index: 566
# 17.166212534059948 % completed. Current Index: 567
# 17.19648804117469 % completed. Current Index: 568
# 17.226763548289433 % completed. Current Index: 569
# 17.257039055404178 % completed. Current Index: 570
# 17.287314562518922 % completed. Current Index: 571
# 17.317590069633667 % completed. Current Index: 572
# 17.34786557674841 % completed. Current Index: 573
# 17.378141083863156 % completed. Current Index: 574
# 17.4084165909779 % completed. Current Index: 575
# 17.43869209809264 % completed. Current Index: 576
# 17.468967605207386 % completed. Current Index: 577
# 17.499243112322134 % completed. Current Index: 578
# 17.529518619436875 % completed. Current Index: 579
# 17.55979412655162 % completed. Current Index: 580
# 17.590069633666364 % completed. Current Index: 581
# 17.620345140781108 % completed. Current Index: 582
# 17.650620647895852 % completed. Current Index: 583
# 17.680896155010597 % completed. Current Index: 584
# 17.71117166212534 % completed. Current Index: 585
# 17.741447169240086 % completed. Current Index: 586
# 17.771722676354827 % completed. Current Index: 587
# 17.80199818346957 % completed. Current Index: 588
# 17.832273690584316 % completed. Current Index: 589
# 17.862549197699064 % completed. Current Index: 590
# 17.892824704813805 % completed. Current Index: 591
# 17.92310021192855 % completed. Current Index: 592
# 17.953375719043294 % completed. Current Index: 593
# 17.983651226158038 % completed. Current Index: 594
# 18.013926733272783 % completed. Current Index: 595
# 18.044202240387527 % completed. Current Index: 596
# 18.07447774750227 % completed. Current Index: 597
# 18.104753254617016 % completed. Current Index: 598
# 18.135028761731757 % completed. Current Index: 599
# 18.1653042688465 % completed. Current Index: 600
# 18.19557977596125 % completed. Current Index: 601
# 18.225855283075994 % completed. Current Index: 602
# 18.256130790190735 % completed. Current Index: 603
# 18.28640629730548 % completed. Current Index: 604
# 18.316681804420224 % completed. Current Index: 605
# 18.34695731153497 % completed. Current Index: 606
# 18.377232818649713 % completed. Current Index: 607
# 18.407508325764457 % completed. Current Index: 608
# 18.4377838328792 % completed. Current Index: 609
# 18.468059339993946 % completed. Current Index: 610
# 18.498334847108687 % completed. Current Index: 611
# 18.52861035422343 % completed. Current Index: 612
# 18.55888586133818 % completed. Current Index: 613
# 18.58916136845292 % completed. Current Index: 614
# 18.619436875567665 % completed. Current Index: 615
# 18.64971238268241 % completed. Current Index: 616
# 18.679987889797154 % completed. Current Index: 617
# 18.7102633969119 % completed. Current Index: 618
# 18.740538904026643 % completed. Current Index: 619
# 18.770814411141387 % completed. Current Index: 620
# 18.80108991825613 % completed. Current Index: 621
# 18.831365425370876 % completed. Current Index: 622
# 18.861640932485617 % completed. Current Index: 623
# 18.89191643960036 % completed. Current Index: 624
# 18.92219194671511 % completed. Current Index: 625
# 18.95246745382985 % completed. Current Index: 626
# 18.982742960944595 % completed. Current Index: 627
# 19.01301846805934 % completed. Current Index: 628
# 19.043293975174084 % completed. Current Index: 629
# 19.07356948228883 % completed. Current Index: 630
# 19.103844989403573 % completed. Current Index: 631
# 19.134120496518317 % completed. Current Index: 632
# 19.164396003633062 % completed. Current Index: 633
# 19.194671510747803 % completed. Current Index: 634
# 19.224947017862547 % completed. Current Index: 635
# 19.255222524977295 % completed. Current Index: 636
# 19.28549803209204 % completed. Current Index: 637
# 19.31577353920678 % completed. Current Index: 638
# 19.346049046321525 % completed. Current Index: 639
# 19.37632455343627 % completed. Current Index: 640
# 19.406600060551014 % completed. Current Index: 641
# 19.43687556766576 % completed. Current Index: 642
# 19.467151074780503 % completed. Current Index: 643
# 19.497426581895247 % completed. Current Index: 644
# 19.527702089009992 % completed. Current Index: 645
# 19.557977596124733 % completed. Current Index: 646
# 19.588253103239477 % completed. Current Index: 647
# 19.618528610354225 % completed. Current Index: 648
# 19.64880411746897 % completed. Current Index: 649
# 19.67907962458371 % completed. Current Index: 650
# 19.709355131698455 % completed. Current Index: 651
# 19.7396306388132 % completed. Current Index: 652
# 19.769906145927944 % completed. Current Index: 653
# 19.80018165304269 % completed. Current Index: 654
# 19.830457160157433 % completed. Current Index: 655
# 19.860732667272178 % completed. Current Index: 656
# 19.891008174386922 % completed. Current Index: 657
# 19.921283681501663 % completed. Current Index: 658
# 19.95155918861641 % completed. Current Index: 659
# 19.981834695731155 % completed. Current Index: 660
# 20.012110202845896 % completed. Current Index: 661
# 20.04238570996064 % completed. Current Index: 662
# 20.072661217075385 % completed. Current Index: 663
# 20.10293672419013 % completed. Current Index: 664
# 20.133212231304874 % completed. Current Index: 665
# 20.16348773841962 % completed. Current Index: 666
# 20.193763245534363 % completed. Current Index: 667
# 20.224038752649108 % completed. Current Index: 668
# 20.254314259763852 % completed. Current Index: 669
# 20.284589766878593 % completed. Current Index: 670
# 20.31486527399334 % completed. Current Index: 671
# 20.345140781108086 % completed. Current Index: 672
# 20.375416288222826 % completed. Current Index: 673
# 20.40569179533757 % completed. Current Index: 674
# 20.435967302452315 % completed. Current Index: 675
# 20.46624280956706 % completed. Current Index: 676
# 20.496518316681804 % completed. Current Index: 677
# 20.52679382379655 % completed. Current Index: 678
# 20.557069330911293 % completed. Current Index: 679
# 20.587344838026038 % completed. Current Index: 680
# 20.61762034514078 % completed. Current Index: 681
# 20.647895852255523 % completed. Current Index: 682
# 20.67817135937027 % completed. Current Index: 683
# 20.708446866485016 % completed. Current Index: 684
# 20.738722373599757 % completed. Current Index: 685
# 20.7689978807145 % completed. Current Index: 686
# 20.799273387829246 % completed. Current Index: 687
# 20.82954889494399 % completed. Current Index: 688
# 20.859824402058734 % completed. Current Index: 689
# 20.89009990917348 % completed. Current Index: 690
# 20.920375416288223 % completed. Current Index: 691
# 20.950650923402968 % completed. Current Index: 692
# 20.98092643051771 % completed. Current Index: 693
# 21.011201937632457 % completed. Current Index: 694
# 21.0414774447472 % completed. Current Index: 695
# 21.071752951861946 % completed. Current Index: 696
# 21.102028458976687 % completed. Current Index: 697
# 21.13230396609143 % completed. Current Index: 698
# 21.162579473206176 % completed. Current Index: 699
# 21.19285498032092 % completed. Current Index: 700
# 21.223130487435665 % completed. Current Index: 701
# 21.25340599455041 % completed. Current Index: 702
# 21.283681501665153 % completed. Current Index: 703
# 21.313957008779898 % completed. Current Index: 704
# 21.34423251589464 % completed. Current Index: 705
# 21.374508023009387 % completed. Current Index: 706
# 21.40478353012413 % completed. Current Index: 707
# 21.435059037238872 % completed. Current Index: 708
# 21.465334544353617 % completed. Current Index: 709
# 21.49561005146836 % completed. Current Index: 710
# 21.525885558583106 % completed. Current Index: 711
# 21.55616106569785 % completed. Current Index: 712
# 21.586436572812595 % completed. Current Index: 713
# 21.61671207992734 % completed. Current Index: 714
# 21.646987587042084 % completed. Current Index: 715
# 21.677263094156825 % completed. Current Index: 716
# 21.707538601271573 % completed. Current Index: 717
# 21.737814108386317 % completed. Current Index: 718
# 21.76808961550106 % completed. Current Index: 719
# 21.798365122615802 % completed. Current Index: 720
# 21.828640629730547 % completed. Current Index: 721
# 21.85891613684529 % completed. Current Index: 722
# 21.88919164396004 % completed. Current Index: 723
# 21.91946715107478 % completed. Current Index: 724
# 21.949742658189525 % completed. Current Index: 725
# 21.98001816530427 % completed. Current Index: 726
# 22.010293672419014 % completed. Current Index: 727
# 22.040569179533755 % completed. Current Index: 728
# 22.070844686648503 % completed. Current Index: 729
# 22.101120193763247 % completed. Current Index: 730
# 22.13139570087799 % completed. Current Index: 731
# 22.161671207992732 % completed. Current Index: 732
# 22.191946715107477 % completed. Current Index: 733
# 22.22222222222222 % completed. Current Index: 734
# 22.252497729336966 % completed. Current Index: 735
# 22.28277323645171 % completed. Current Index: 736
# 22.313048743566455 % completed. Current Index: 737
# 22.3433242506812 % completed. Current Index: 738
# 22.373599757795944 % completed. Current Index: 739
# 22.403875264910685 % completed. Current Index: 740
# 22.434150772025433 % completed. Current Index: 741
# 22.464426279140177 % completed. Current Index: 742
# 22.494701786254918 % completed. Current Index: 743
# 22.524977293369663 % completed. Current Index: 744
# 22.555252800484407 % completed. Current Index: 745
# 22.585528307599155 % completed. Current Index: 746
# 22.615803814713896 % completed. Current Index: 747
# 22.64607932182864 % completed. Current Index: 748
# 22.676354828943385 % completed. Current Index: 749
# 22.70663033605813 % completed. Current Index: 750
# 22.73690584317287 % completed. Current Index: 751
# 22.76718135028762 % completed. Current Index: 752
# 22.797456857402363 % completed. Current Index: 753
# 22.827732364517107 % completed. Current Index: 754
# 22.858007871631848 % completed. Current Index: 755
# 22.888283378746593 % completed. Current Index: 756
# 22.918558885861337 % completed. Current Index: 757
# 22.948834392976085 % completed. Current Index: 758
# 22.979109900090826 % completed. Current Index: 759
# 23.00938540720557 % completed. Current Index: 760
# 23.039660914320315 % completed. Current Index: 761
# 23.06993642143506 % completed. Current Index: 762
# 23.1002119285498 % completed. Current Index: 763
# 23.13048743566455 % completed. Current Index: 764
# 23.160762942779293 % completed. Current Index: 765
# 23.191038449894037 % completed. Current Index: 766
# 23.22131395700878 % completed. Current Index: 767
# 23.251589464123523 % completed. Current Index: 768
# 23.281864971238267 % completed. Current Index: 769
# 23.31214047835301 % completed. Current Index: 770
# 23.342415985467756 % completed. Current Index: 771
# 23.3726914925825 % completed. Current Index: 772
# 23.402966999697245 % completed. Current Index: 773
# 23.43324250681199 % completed. Current Index: 774
# 23.463518013926734 % completed. Current Index: 775
# 23.49379352104148 % completed. Current Index: 776
# 23.524069028156223 % completed. Current Index: 777
# 23.554344535270964 % completed. Current Index: 778
# 23.58462004238571 % completed. Current Index: 779
# 23.614895549500453 % completed. Current Index: 780
# 23.6451710566152 % completed. Current Index: 781
# 23.675446563729942 % completed. Current Index: 782
# 23.705722070844686 % completed. Current Index: 783
# 23.73599757795943 % completed. Current Index: 784
# 23.766273085074175 % completed. Current Index: 785
# 23.79654859218892 % completed. Current Index: 786
# 23.826824099303664 % completed. Current Index: 787
# 23.85709960641841 % completed. Current Index: 788
# 23.887375113533153 % completed. Current Index: 789
# 23.917650620647894 % completed. Current Index: 790
# 23.94792612776264 % completed. Current Index: 791
# 23.978201634877383 % completed. Current Index: 792
# 24.00847714199213 % completed. Current Index: 793
# 24.038752649106872 % completed. Current Index: 794
# 24.069028156221616 % completed. Current Index: 795
# 24.09930366333636 % completed. Current Index: 796
# 24.129579170451105 % completed. Current Index: 797
# 24.159854677565846 % completed. Current Index: 798
# 24.190130184680594 % completed. Current Index: 799
# 24.22040569179534 % completed. Current Index: 800
# 24.250681198910083 % completed. Current Index: 801
# 24.280956706024824 % completed. Current Index: 802
# 24.31123221313957 % completed. Current Index: 803
# 24.341507720254317 % completed. Current Index: 804
# 24.371783227369058 % completed. Current Index: 805
# 24.402058734483802 % completed. Current Index: 806
# 24.432334241598546 % completed. Current Index: 807
# 24.46260974871329 % completed. Current Index: 808
# 24.492885255828035 % completed. Current Index: 809
# 24.52316076294278 % completed. Current Index: 810
# 24.553436270057524 % completed. Current Index: 811
# 24.58371177717227 % completed. Current Index: 812
# 24.613987284287013 % completed. Current Index: 813
# 24.644262791401754 % completed. Current Index: 814
# 24.6745382985165 % completed. Current Index: 815
# 24.704813805631247 % completed. Current Index: 816
# 24.735089312745988 % completed. Current Index: 817
# 24.765364819860732 % completed. Current Index: 818
# 24.795640326975477 % completed. Current Index: 819
# 24.82591583409022 % completed. Current Index: 820
# 24.856191341204966 % completed. Current Index: 821
# 24.88646684831971 % completed. Current Index: 822
# 24.916742355434454 % completed. Current Index: 823
# 24.9470178625492 % completed. Current Index: 824
# 24.97729336966394 % completed. Current Index: 825
# 25.007568876778684 % completed. Current Index: 826
# 25.037844383893432 % completed. Current Index: 827
# 25.068119891008173 % completed. Current Index: 828
# 25.098395398122918 % completed. Current Index: 829
# 25.12867090523766 % completed. Current Index: 830
# 25.158946412352407 % completed. Current Index: 831
# 25.18922191946715 % completed. Current Index: 832
# 25.219497426581896 % completed. Current Index: 833
# 25.24977293369664 % completed. Current Index: 834
# 25.28004844081138 % completed. Current Index: 835
# 25.31032394792613 % completed. Current Index: 836
# 25.340599455040874 % completed. Current Index: 837
# 25.370874962155614 % completed. Current Index: 838
# 25.401150469270362 % completed. Current Index: 839
# 25.431425976385103 % completed. Current Index: 840
# 25.461701483499848 % completed. Current Index: 841
# 25.491976990614596 % completed. Current Index: 842
# 25.522252497729337 % completed. Current Index: 843
# 25.55252800484408 % completed. Current Index: 844
# 25.582803511958822 % completed. Current Index: 845
# 25.61307901907357 % completed. Current Index: 846
# 25.64335452618831 % completed. Current Index: 847
# 25.67363003330306 % completed. Current Index: 848
# 25.703905540417804 % completed. Current Index: 849
# 25.734181047532545 % completed. Current Index: 850
# 25.764456554647293 % completed. Current Index: 851
# 25.794732061762033 % completed. Current Index: 852
# 25.825007568876778 % completed. Current Index: 853
# 25.855283075991526 % completed. Current Index: 854
# 25.885558583106267 % completed. Current Index: 855
# 25.91583409022101 % completed. Current Index: 856
# 25.946109597335752 % completed. Current Index: 857
# 25.9763851044505 % completed. Current Index: 858
# 26.00666061156524 % completed. Current Index: 859
# 26.03693611867999 % completed. Current Index: 860
# 26.067211625794734 % completed. Current Index: 861
# 26.097487132909475 % completed. Current Index: 862
# 26.127762640024223 % completed. Current Index: 863
# 26.158038147138964 % completed. Current Index: 864
# 26.188313654253708 % completed. Current Index: 865
# 26.218589161368456 % completed. Current Index: 866
# 26.248864668483197 % completed. Current Index: 867
# 26.27914017559794 % completed. Current Index: 868
# 26.309415682712682 % completed. Current Index: 869
# 26.33969118982743 % completed. Current Index: 870
# 26.369966696942175 % completed. Current Index: 871
# 26.400242204056916 % completed. Current Index: 872
# 26.430517711171664 % completed. Current Index: 873
# 26.460793218286405 % completed. Current Index: 874
# 26.491068725401153 % completed. Current Index: 875
# 26.521344232515894 % completed. Current Index: 876
# 26.551619739630638 % completed. Current Index: 877
# 26.581895246745386 % completed. Current Index: 878
# 26.612170753860127 % completed. Current Index: 879
# 26.64244626097487 % completed. Current Index: 880
# 26.672721768089612 % completed. Current Index: 881
# 26.70299727520436 % completed. Current Index: 882
# 26.733272782319105 % completed. Current Index: 883
# 26.763548289433846 % completed. Current Index: 884
# 26.793823796548594 % completed. Current Index: 885
# 26.824099303663335 % completed. Current Index: 886
# 26.854374810778083 % completed. Current Index: 887
# 26.88465031789282 % completed. Current Index: 888
# 26.91492582500757 % completed. Current Index: 889
# 26.945201332122316 % completed. Current Index: 890
# 26.975476839237057 % completed. Current Index: 891
# 27.0057523463518 % completed. Current Index: 892
# 27.036027853466543 % completed. Current Index: 893
# 27.06630336058129 % completed. Current Index: 894
# 27.096578867696035 % completed. Current Index: 895
# 27.126854374810776 % completed. Current Index: 896
# 27.157129881925524 % completed. Current Index: 897
# 27.187405389040265 % completed. Current Index: 898
# 27.21768089615501 % completed. Current Index: 899
# 27.247956403269757 % completed. Current Index: 900
# 27.2782319103845 % completed. Current Index: 901
# 27.308507417499246 % completed. Current Index: 902
# 27.338782924613987 % completed. Current Index: 903
# 27.36905843172873 % completed. Current Index: 904
# 27.399333938843473 % completed. Current Index: 905
# 27.42960944595822 % completed. Current Index: 906
# 27.459884953072965 % completed. Current Index: 907
# 27.490160460187706 % completed. Current Index: 908
# 27.520435967302454 % completed. Current Index: 909
# 27.550711474417195 % completed. Current Index: 910
# 27.58098698153194 % completed. Current Index: 911
# 27.611262488646688 % completed. Current Index: 912
# 27.64153799576143 % completed. Current Index: 913
# 27.671813502876176 % completed. Current Index: 914
# 27.702089009990914 % completed. Current Index: 915
# 27.732364517105662 % completed. Current Index: 916
# 27.762640024220403 % completed. Current Index: 917
# 27.79291553133515 % completed. Current Index: 918
# 27.823191038449895 % completed. Current Index: 919
# 27.853466545564636 % completed. Current Index: 920
# 27.883742052679384 % completed. Current Index: 921
# 27.914017559794125 % completed. Current Index: 922
# 27.94429306690887 % completed. Current Index: 923
# 27.974568574023618 % completed. Current Index: 924
# 28.00484408113836 % completed. Current Index: 925
# 28.035119588253103 % completed. Current Index: 926
# 28.065395095367844 % completed. Current Index: 927
# 28.095670602482592 % completed. Current Index: 928
# 28.12594610959734 % completed. Current Index: 929
# 28.15622161671208 % completed. Current Index: 930
# 28.186497123826825 % completed. Current Index: 931
# 28.216772630941566 % completed. Current Index: 932
# 28.247048138056314 % completed. Current Index: 933
# 28.277323645171055 % completed. Current Index: 934
# 28.3075991522858 % completed. Current Index: 935
# 28.337874659400548 % completed. Current Index: 936
# 28.36815016651529 % completed. Current Index: 937
# 28.398425673630033 % completed. Current Index: 938
# 28.428701180744774 % completed. Current Index: 939
# 28.458976687859522 % completed. Current Index: 940
# 28.48925219497427 % completed. Current Index: 941
# 28.519527702089007 % completed. Current Index: 942
# 28.549803209203755 % completed. Current Index: 943
# 28.580078716318496 % completed. Current Index: 944
# 28.610354223433244 % completed. Current Index: 945
# 28.640629730547985 % completed. Current Index: 946
# 28.67090523766273 % completed. Current Index: 947
# 28.701180744777478 % completed. Current Index: 948
# 28.73145625189222 % completed. Current Index: 949
# 28.761731759006963 % completed. Current Index: 950
# 28.792007266121704 % completed. Current Index: 951
# ...
# 35.694822888283376 % completed. Current Index: 1179
# 35.72509839539813 % completed. Current Index: 1180
# 35.755373902512865 % completed. Current Index: 1181
# 35.78564940962761 % completed. Current Index: 1182
# 35.815924916742354 % completed. Current Index: 1183
# 35.8462004238571 % completed. Current Index: 1184
# 35.87647593097184 % completed. Current Index: 1185
# 35.90675143808659 % completed. Current Index: 1186
# 35.93702694520133 % completed. Current Index: 1187
# 35.967302452316076 % completed. Current Index: 1188
# 35.99757795943082 % completed. Current Index: 1189
# 36.027853466545565 % completed. Current Index: 1190
# 36.05812897366031 % completed. Current Index: 1191
# 36.088404480775054 % completed. Current Index: 1192
# 36.1186799878898 % completed. Current Index: 1193
# 36.14895549500454 % completed. Current Index: 1194
# 36.17923100211928 % completed. Current Index: 1195
# 36.20950650923403 % completed. Current Index: 1196
# 36.23978201634878 % completed. Current Index: 1197
# 36.270057523463514 % completed. Current Index: 1198
# 36.300333030578265 % completed. Current Index: 1199
# 36.330608537693 % completed. Current Index: 1200
# 36.36088404480775 % completed. Current Index: 1201
# 36.3911595519225 % completed. Current Index: 1202
# 36.421435059037236 % completed. Current Index: 1203
# 36.45171056615199 % completed. Current Index: 1204
# 36.481986073266725 % completed. Current Index: 1205
# 36.51226158038147 % completed. Current Index: 1206
# 36.542537087496214 % completed. Current Index: 1207
# 36.57281259461096 % completed. Current Index: 1208
# 36.6030881017257 % completed. Current Index: 1209
# 36.63336360884045 % completed. Current Index: 1210
# 36.66363911595519 % completed. Current Index: 1211
# 36.69391462306994 % completed. Current Index: 1212
# 36.72419013018468 % completed. Current Index: 1213
# 36.754465637299425 % completed. Current Index: 1214
# 36.78474114441417 % completed. Current Index: 1215
# 36.815016651528914 % completed. Current Index: 1216
# 36.84529215864366 % completed. Current Index: 1217
# 36.8755676657584 % completed. Current Index: 1218
# 36.90584317287314 % completed. Current Index: 1219
# 36.93611867998789 % completed. Current Index: 1220
# 36.96639418710264 % completed. Current Index: 1221
# 36.996669694217374 % completed. Current Index: 1222
# 37.026945201332126 % completed. Current Index: 1223
# 37.05722070844686 % completed. Current Index: 1224
# 37.08749621556161 % completed. Current Index: 1225
# 37.11777172267636 % completed. Current Index: 1226
# 37.148047229791096 % completed. Current Index: 1227
# 37.17832273690584 % completed. Current Index: 1228
# 37.208598244020585 % completed. Current Index: 1229
# 37.23887375113533 % completed. Current Index: 1230
# 37.26914925825008 % completed. Current Index: 1231
# 37.29942476536482 % completed. Current Index: 1232
# 37.32970027247956 % completed. Current Index: 1233
# 37.35997577959431 % completed. Current Index: 1234
# 37.39025128670905 % completed. Current Index: 1235
# 37.4205267938238 % completed. Current Index: 1236
# 37.45080230093854 % completed. Current Index: 1237
# 37.481077808053286 % completed. Current Index: 1238
# 37.51135331516803 % completed. Current Index: 1239
# 37.541628822282775 % completed. Current Index: 1240
# 37.57190432939751 % completed. Current Index: 1241
# 37.60217983651226 % completed. Current Index: 1242
# 37.63245534362701 % completed. Current Index: 1243
# 37.66273085074175 % completed. Current Index: 1244
# 37.6930063578565 % completed. Current Index: 1245
# 37.723281864971234 % completed. Current Index: 1246
# 37.753557372085986 % completed. Current Index: 1247
# 37.78383287920072 % completed. Current Index: 1248
# 37.81410838631547 % completed. Current Index: 1249
# 37.84438389343022 % completed. Current Index: 1250
# 37.87465940054496 % completed. Current Index: 1251
# 37.9049349076597 % completed. Current Index: 1252
# 37.935210414774446 % completed. Current Index: 1253
# 37.96548592188919 % completed. Current Index: 1254
# 37.995761429003934 % completed. Current Index: 1255
# 38.02603693611868 % completed. Current Index: 1256
# 38.05631244323342 % completed. Current Index: 1257
# 38.08658795034817 % completed. Current Index: 1258
# 38.11686345746291 % completed. Current Index: 1259
# 38.14713896457766 % completed. Current Index: 1260
# 38.1774144716924 % completed. Current Index: 1261
# 38.207689978807146 % completed. Current Index: 1262
# 38.23796548592189 % completed. Current Index: 1263
# 38.268240993036635 % completed. Current Index: 1264
# 38.29851650015137 % completed. Current Index: 1265
# 38.328792007266124 % completed. Current Index: 1266
# 38.35906751438087 % completed. Current Index: 1267
# 38.389343021495606 % completed. Current Index: 1268
# 38.41961852861036 % completed. Current Index: 1269
# 38.449894035725094 % completed. Current Index: 1270
# 38.480169542839846 % completed. Current Index: 1271
# 38.51044504995459 % completed. Current Index: 1272
# 38.54072055706933 % completed. Current Index: 1273
# 38.57099606418408 % completed. Current Index: 1274
# 38.60127157129882 % completed. Current Index: 1275
# 38.63154707841356 % completed. Current Index: 1276
# 38.661822585528306 % completed. Current Index: 1277
# 38.69209809264305 % completed. Current Index: 1278
# 38.722373599757795 % completed. Current Index: 1279
# 38.75264910687254 % completed. Current Index: 1280
# 38.782924613987284 % completed. Current Index: 1281
# 38.81320012110203 % completed. Current Index: 1282
# 38.84347562821677 % completed. Current Index: 1283
# 38.87375113533152 % completed. Current Index: 1284
# 38.90402664244626 % completed. Current Index: 1285
# 38.934302149561006 % completed. Current Index: 1286
# 38.96457765667575 % completed. Current Index: 1287
# 38.994853163790495 % completed. Current Index: 1288
# 39.02512867090524 % completed. Current Index: 1289
# 39.055404178019984 % completed. Current Index: 1290
# 39.08567968513473 % completed. Current Index: 1291
# 39.115955192249466 % completed. Current Index: 1292
# 39.14623069936422 % completed. Current Index: 1293
# 39.176506206478955 % completed. Current Index: 1294
# 39.2067817135937 % completed. Current Index: 1295
# 39.23705722070845 % completed. Current Index: 1296
# 39.26733272782319 % completed. Current Index: 1297
# 39.29760823493794 % completed. Current Index: 1298
# 39.32788374205268 % completed. Current Index: 1299
# 39.35815924916742 % completed. Current Index: 1300
# 39.38843475628217 % completed. Current Index: 1301
# 39.41871026339691 % completed. Current Index: 1302
# 39.448985770511655 % completed. Current Index: 1303
# 39.4792612776264 % completed. Current Index: 1304
# 39.509536784741144 % completed. Current Index: 1305
# 39.53981229185589 % completed. Current Index: 1306
# 39.57008779897063 % completed. Current Index: 1307
# 39.60036330608538 % completed. Current Index: 1308
# 39.63063881320012 % completed. Current Index: 1309
# 39.660914320314866 % completed. Current Index: 1310
# 39.69118982742961 % completed. Current Index: 1311
# 39.721465334544355 % completed. Current Index: 1312
# 39.7517408416591 % completed. Current Index: 1313
# 39.782016348773844 % completed. Current Index: 1314
# 39.81229185588859 % completed. Current Index: 1315
# 39.842567363003326 % completed. Current Index: 1316
# 39.87284287011808 % completed. Current Index: 1317
# 39.90311837723282 % completed. Current Index: 1318
# 39.93339388434756 % completed. Current Index: 1319
# 39.96366939146231 % completed. Current Index: 1320
# 39.99394489857705 % completed. Current Index: 1321
# 40.02422040569179 % completed. Current Index: 1322
# 40.05449591280654 % completed. Current Index: 1323
# 40.08477141992128 % completed. Current Index: 1324
# 40.11504692703603 % completed. Current Index: 1325
# 40.14532243415077 % completed. Current Index: 1326
# 40.175597941265515 % completed. Current Index: 1327
# 40.20587344838026 % completed. Current Index: 1328
# 40.236148955495004 % completed. Current Index: 1329
# 40.26642446260975 % completed. Current Index: 1330
# 40.29669996972449 % completed. Current Index: 1331
# 40.32697547683924 % completed. Current Index: 1332
# 40.35725098395398 % completed. Current Index: 1333
# 40.387526491068726 % completed. Current Index: 1334
# 40.417801998183464 % completed. Current Index: 1335
# 40.448077505298215 % completed. Current Index: 1336
# 40.47835301241296 % completed. Current Index: 1337
# 40.508628519527704 % completed. Current Index: 1338
# 40.53890402664245 % completed. Current Index: 1339
# 40.569179533757186 % completed. Current Index: 1340
# 40.59945504087194 % completed. Current Index: 1341
# 40.62973054798668 % completed. Current Index: 1342
# 40.66000605510142 % completed. Current Index: 1343
# 40.69028156221617 % completed. Current Index: 1344
# 40.72055706933091 % completed. Current Index: 1345
# 40.75083257644565 % completed. Current Index: 1346
# 40.781108083560405 % completed. Current Index: 1347
# 40.81138359067514 % completed. Current Index: 1348
# 40.841659097789886 % completed. Current Index: 1349
# 40.87193460490463 % completed. Current Index: 1350
# 40.902210112019375 % completed. Current Index: 1351
# 40.93248561913412 % completed. Current Index: 1352
# 40.962761126248864 % completed. Current Index: 1353
# 40.99303663336361 % completed. Current Index: 1354
# 41.02331214047835 % completed. Current Index: 1355
# 41.0535876475931 % completed. Current Index: 1356
# 41.08386315470784 % completed. Current Index: 1357
# 41.11413866182259 % completed. Current Index: 1358
# 41.14441416893733 % completed. Current Index: 1359
# 41.174689676052076 % completed. Current Index: 1360
# 41.20496518316682 % completed. Current Index: 1361
# 41.23524069028156 % completed. Current Index: 1362
# 41.26551619739631 % completed. Current Index: 1363
# 41.295791704511046 % completed. Current Index: 1364
# 41.3260672116258 % completed. Current Index: 1365
# 41.35634271874054 % completed. Current Index: 1366
# 41.38661822585528 % completed. Current Index: 1367
# 41.41689373297003 % completed. Current Index: 1368
# 41.44716924008477 % completed. Current Index: 1369
# 41.47744474719951 % completed. Current Index: 1370
# 41.507720254314265 % completed. Current Index: 1371
# 41.537995761429 % completed. Current Index: 1372
# 41.56827126854375 % completed. Current Index: 1373
# 41.59854677565849 % completed. Current Index: 1374
# 41.628822282773235 % completed. Current Index: 1375
# 41.65909778988798 % completed. Current Index: 1376
# 41.689373297002724 % completed. Current Index: 1377
# 41.71964880411747 % completed. Current Index: 1378
# 41.74992431123221 % completed. Current Index: 1379
# 41.78019981834696 % completed. Current Index: 1380
# 41.8104753254617 % completed. Current Index: 1381
# 41.84075083257645 % completed. Current Index: 1382
# 41.87102633969119 % completed. Current Index: 1383
# 41.901301846805936 % completed. Current Index: 1384
# 41.93157735392068 % completed. Current Index: 1385
# 41.96185286103542 % completed. Current Index: 1386
# 41.99212836815017 % completed. Current Index: 1387
# 42.022403875264914 % completed. Current Index: 1388
# 42.05267938237965 % completed. Current Index: 1389
# 42.0829548894944 % completed. Current Index: 1390
# 42.11323039660914 % completed. Current Index: 1391
# 42.14350590372389 % completed. Current Index: 1392
# 42.17378141083863 % completed. Current Index: 1393
# 42.20405691795337 % completed. Current Index: 1394
# 42.234332425068125 % completed. Current Index: 1395
# 42.26460793218286 % completed. Current Index: 1396
# 42.29488343929761 % completed. Current Index: 1397
# 42.32515894641235 % completed. Current Index: 1398
# 42.355434453527096 % completed. Current Index: 1399
# 42.38570996064184 % completed. Current Index: 1400
# 42.415985467756585 % completed. Current Index: 1401
# 42.44626097487133 % completed. Current Index: 1402
# 42.476536481986074 % completed. Current Index: 1403
# 42.50681198910082 % completed. Current Index: 1404
# 42.53708749621556 % completed. Current Index: 1405
# 42.56736300333031 % completed. Current Index: 1406
# 42.59763851044505 % completed. Current Index: 1407
# 42.627914017559796 % completed. Current Index: 1408
# 42.65818952467454 % completed. Current Index: 1409
# 42.68846503178928 % completed. Current Index: 1410
# 42.71874053890403 % completed. Current Index: 1411
# 42.749016046018774 % completed. Current Index: 1412
# 42.77929155313351 % completed. Current Index: 1413
# 42.80956706024826 % completed. Current Index: 1414
# 42.839842567363 % completed. Current Index: 1415
# 42.870118074477745 % completed. Current Index: 1416
# 42.900393581592496 % completed. Current Index: 1417
# 42.93066908870723 % completed. Current Index: 1418
# 42.960944595821985 % completed. Current Index: 1419
# 42.99122010293672 % completed. Current Index: 1420
# 43.02149561005147 % completed. Current Index: 1421
# 43.05177111716621 % completed. Current Index: 1422
# 43.082046624280956 % completed. Current Index: 1423
# 43.1123221313957 % completed. Current Index: 1424
# 43.142597638510445 % completed. Current Index: 1425
# 43.17287314562519 % completed. Current Index: 1426
# 43.203148652739934 % completed. Current Index: 1427
# 43.23342415985468 % completed. Current Index: 1428
# 43.26369966696942 % completed. Current Index: 1429
# 43.29397517408417 % completed. Current Index: 1430
# 43.32425068119891 % completed. Current Index: 1431
# 43.35452618831365 % completed. Current Index: 1432
# 43.3848016954284 % completed. Current Index: 1433
# 43.415077202543145 % completed. Current Index: 1434
# 43.44535270965789 % completed. Current Index: 1435
# 43.475628216772634 % completed. Current Index: 1436
# 43.50590372388737 % completed. Current Index: 1437
# 43.53617923100212 % completed. Current Index: 1438
# 43.56645473811686 % completed. Current Index: 1439
# 43.596730245231605 % completed. Current Index: 1440
# 43.627005752346356 % completed. Current Index: 1441
# 43.657281259461094 % completed. Current Index: 1442
# 43.68755676657584 % completed. Current Index: 1443
# 43.71783227369058 % completed. Current Index: 1444
# 43.74810778080533 % completed. Current Index: 1445
# 43.77838328792008 % completed. Current Index: 1446
# 43.808658795034816 % completed. Current Index: 1447
# 43.83893430214956 % completed. Current Index: 1448
# 43.869209809264305 % completed. Current Index: 1449
# 43.89948531637905 % completed. Current Index: 1450
# 43.929760823493794 % completed. Current Index: 1451
# 43.96003633060854 % completed. Current Index: 1452
# 43.99031183772328 % completed. Current Index: 1453
# 44.02058734483803 % completed. Current Index: 1454
# 44.05086285195277 % completed. Current Index: 1455
# 44.08113835906751 % completed. Current Index: 1456
# 44.11141386618226 % completed. Current Index: 1457
# 44.141689373297005 % completed. Current Index: 1458
# 44.17196488041174 % completed. Current Index: 1459
# 44.202240387526494 % completed. Current Index: 1460
# 44.23251589464123 % completed. Current Index: 1461
# 44.26279140175598 % completed. Current Index: 1462
# 44.29306690887073 % completed. Current Index: 1463
# 44.323342415985465 % completed. Current Index: 1464
# 44.35361792310022 % completed. Current Index: 1465
# 44.383893430214954 % completed. Current Index: 1466
# 44.4141689373297 % completed. Current Index: 1467
# 44.44444444444444 % completed. Current Index: 1468
# 44.47471995155919 % completed. Current Index: 1469
# 44.50499545867393 % completed. Current Index: 1470
# 44.535270965788676 % completed. Current Index: 1471
# 44.56554647290342 % completed. Current Index: 1472
# 44.595821980018165 % completed. Current Index: 1473
# 44.62609748713291 % completed. Current Index: 1474
# 44.656372994247654 % completed. Current Index: 1475
# 44.6866485013624 % completed. Current Index: 1476
# 44.71692400847714 % completed. Current Index: 1477
# 44.74719951559189 % completed. Current Index: 1478
# 44.77747502270663 % completed. Current Index: 1479
# 44.80775052982137 % completed. Current Index: 1480
# 44.83802603693612 % completed. Current Index: 1481
# 44.868301544050865 % completed. Current Index: 1482
# 44.8985770511656 % completed. Current Index: 1483
# 44.928852558280354 % completed. Current Index: 1484
# 44.95912806539509 % completed. Current Index: 1485
# 44.989403572509836 % completed. Current Index: 1486
# 45.01967907962459 % completed. Current Index: 1487
# 45.049954586739325 % completed. Current Index: 1488
# 45.08023009385408 % completed. Current Index: 1489
# 45.110505600968814 % completed. Current Index: 1490

# %%
df['context'] = "1." + df.context

# %%
df.head()
# Out:
#          title              heading  \
# 0  Agriculture              Summary
# 1  Agriculture  Etymology and scope
# 2  Agriculture              Origins
# 3  Agriculture        Civilizations
# 4  Agriculture           Revolution
#
#                                              content  tokens  \
# 0  Agriculture encompasses crop and livestock pro...     467
# 1  The word agriculture is a late Middle English ...     170
# 2  The development of agriculture enabled the hum...     441
# 3  In Eurasia, the Sumerians started to live in v...     878
# 4  In the Middle Ages, compared to the Roman peri...     343
#
#                                              context
# 0  1.Agriculture\nSummary\n\nxAgriculture encompa...
# 1  1.Agriculture\nEtymology and scope\n\nxThe wor...
# 2  1.Agriculture\nOrigins\n\nxThe development of ...
# 3  1.Agriculture\nCivilizations\n\nxIn Eurasia, t...
# 4  1.Agriculture\nRevolution\n\nxIn the Middle Ag...

# %% [markdown]
# The prompt is designed to generate a number of questions. Example questions above were generated based on the summary section of the 2020 Summer Olympics page.
#
# We can observe that the questions 3 and 5 above repeat. Sometimes the generated questions could be ambiguous without the context. We will show that even despite these limitations we can create a successful model.

# %%
print(df.content.values[0])
# Out:
# The 2020 Summer Olympics (Japanese: 2020年夏季オリンピック, Hepburn: Nisen Nijū-nen Kaki Orinpikku), officially the Games of the XXXII Olympiad (第三十二回オリンピック競技大会, Dai Sanjūni-kai Orinpikku Kyōgi Taikai) and branded as Tokyo 2020 (東京2020, Tōkyō Nii Zero Nii Zero), was an international multi-sport event held from 23 July to 8 August 2021 in Tokyo, Japan, with some preliminary events that began on 21 July.
# Tokyo was selected as the host city during the 125th IOC Session in Buenos Aires, Argentina, on 7 September 2013. Originally scheduled to take place from 24 July to 9 August 2020, the event was postponed to 2021 in March 2020 as a result of the COVID-19 pandemic, the first such instance in the history of the Olympic Games (previous games had been cancelled but not rescheduled). However, the event retained the Tokyo 2020 name for marketing and branding purposes. It was largely held behind closed doors with no public spectators permitted due to the declaration of a state of emergency in the Greater Tokyo Area in response to the pandemic. The Summer Paralympics were held between 24 August and 5 September 2021, 16 days after the completion of the Olympics.The 2020 Games were the fourth Olympic Games to be held in Japan, following the Tokyo 1964 (Summer), Sapporo 1972 (Winter) and Nagano 1998 (Winter) games. Tokyo is the first city in Asia to hold the Summer Games twice. The 2020 Games were the second of three consecutive Olympics to be held in East Asia, following the 2018 Winter Olympics in Pyeongchang, South Korea and preceding the 2022 Winter Olympics in Beijing, China.
# New events were introduced in existing sports for 2020, including 3x3 basketball, freestyle BMX and mixed gender team events in a number of existing sports, as well as the return of madison cycling for men and an introduction of the same event for women. New IOC policies also allowed the host organizing committee to add new sports to the Olympic program for just one Games. The disciplines added by the Japanese Olympic Committee were baseball and softball, karate, sport climbing, surfing and skateboarding, the last four of which made their Olympic debuts, and the last three of which will remain on the Olympic program.The United States topped the medal count by both total golds (39) and total medals (113), with China finishing second by both respects (38 and 88). Host nation Japan finished third, setting a record for the most gold medals and total medals ever won by their delegation at an Olympic Games with 27 and 58. Great Britain finished fourth, with a total of 22 gold and 65 medals, becoming the first nation at the Summer Olympics to increase or equal their total medals won in the two Games subsequent to hosting them. The Russian delegation competing as the ROC (not to be confused with the Republic of China (Taiwan) which competed as Chinese Taipei, not ROC) finished fifth with 20 gold medals and third in the overall medal count, with 71 medals. Bermuda, the Philippines and Qatar won their first-ever Olympic gold medals. Burkina Faso, San Marino and Turkmenistan won their first-ever Olympic medals.

# %% [markdown]
# ## 2.3 Create answers based on the context
# Use davinci-instruct to answer the questions given the relevant Wikipedia section contents
#
# Note: We have used temperature=0, but it may be beneficial to experiment with a higher temperature to get a higher diversity of questions.
#
# <span style="color:orange">**WARNING: This step will last a long time, and consume a lot of tokens, as it calls davinci-instruct for every section to answer all the questions.**</span>

# %%
def get_answers(row):
    try:
        response = openai.Completion.create(
            engine="davinci-instruct-beta-v3",
            prompt=f"Write answer based on the text below\n\nText: {row.context}\n\nQuestions:\n{row.questions}\n\nAnswers:\n1.",
            temperature=0,
            max_tokens=257,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0
        )
        return response['choices'][0]['text']
    except Exception as e:
        print (e)
        return ""


df['answers']= df.apply(get_answers, axis=1)
df['answers'] = "1." + df.answers
df = df.dropna().reset_index().drop('index',axis=1)
print(df[['answers']].values[0][0])
# Out:
# 1. The 2020 Summer Olympics is an international multi-sport event held from 23 July to 8 August 2021 in Tokyo, Japan.
# 2. The 2020 Summer Olympics took place from 23 July to 8 August 2021.
# 3. The United States topped the medal count by both total golds (39) and total medals (113), with China finishing second by both respects (38 and 88).
# 4. The United States topped the medal count by both total golds (39) and total medals (113), with China finishing second by both respects (38 and 88).
# 5. The United States topped the medal count by both total golds (39) and total medals (113), with China finishing second by both respects (38 and 88).

# %% [markdown]
# These are the answers to the questions above based on the context around the host city selection.
#
# We can see that answers 3-5 contain the correct answer, but instead of answering the question directly, the answer is a verbatim extraction. Despite these occasional lower quality answers, we will show that the model can learn the task reasonably well, given a high number of examples.

# %% [markdown]
# ## 2.4 Save the Olympics Q&A dataset based on Wikipedia sections
# We save the file for use in the [next notebook](olympics-3-train-qa.ipynb)

# %%
df.to_csv('agriculture_qa.csv', index=False)

# %% [markdown]
# ## 2.5 Search file (DEPRECATED)
# We create a search file ([API reference](https://beta.openai.com/docs/api-reference/files/list)), which can be used to retrieve the relevant context when a question is asked.
#
# <span style="color:orange; font-weight:bold">DEPRECATED: The /search endpoint is deprecated in favour of using embeddings. Embeddings are cheaper, faster and can support a better search experience. See <a href="https://github.com/openai/openai-cookbook/blob/main/examples/Question_answering_using_embeddings.ipynb">Question Answering Guide</a> for a search implementation using the embeddings</span>

# %%
df = df[df.tokens<2000]
df[['context', 'tokens']].rename(columns={'context':'text','tokens':'metadata'}).to_json('olympics-data/olympics_search.jsonl', orient='records', lines=True)

search_file = openai.File.create(
  file=open("olympics-data/olympics_search.jsonl"),
  purpose='search'
)
olympics_search_fileid = search_file['id']

# %% [markdown]
# ## 2.6 Answer questions based on the context provided
#
# We will use a simple implementation of the answers endpoint. This works by simply using the [/search endpoint](https://beta.openai.com/docs/api-reference/searches), which searches over an indexed file to obtain the relevant sections which can be included in the context, following by a question and answering prompt given a specified model.

# %%
from answers_with_ft import create_context, answer_question
print(create_context("Where did women's 4 x 100 metres relay event take place during the 2020 Summer Olympics?", olympics_search_fileid, max_len=400))
# Out:
# Athletics at the 2020 Summer Olympics – Women's 4 × 100 metres relay
# Summary
#
# The women's 4 × 100 metres relay event at the 2020 Summer Olympics took place on 5 and 6 August 2021 at the Japan National Stadium. There were 16 competing relay teams, with each team having 5 members from which 4 were selected in each round.
#
# ###
#
# Athletics at the 2020 Summer Olympics – Men's 4 × 100 metres relay
# Qualification
#
# National Olympic Committees (NOCs) could qualify one relay team in one of three following ways:
# The top 8 NOCs at the 2019 World Athletics Championships qualified a relay team.
# The top 8 NOCs at the 2021 World Athletics Relays qualified a relay team.
# Where an NOC placed in the top 8 at both the 2019 World Championships and the 2021 World Relays, the quota place was allocated to the world top list as of 29 June 2021. In this case, 4 teams did so, so there are 4 places available through the world rankings.A total of five athletes may be entered for a relay team. Should a NOC have also entered individual athletes in the corresponding individual event (100 m), the entered individual athletes must be included in the total of five (5) athletes entered for the relay event. In addition of five, NOCs can nominate a maximum of one alternate athlete for each team.
# The qualifying period was originally from 1 May 2019 to 29 June 2020. Due to the COVID-19 pandemic, the period was suspended from 6 April 2020 to 30 November 2020, with the end date extended to 29 June 2021. The qualifying time standards could be obtained in various meets during the given period that have the approval of the IAAF. Both indoor and outdoor meets are eligible. The most recent Area Championships may be counted in the ranking, even if not during the qualifying period.

# %%
answer_question(olympics_search_fileid, "davinci-instruct-beta-v3", 
            "Where did women's 4 x 100 metres relay event take place during the 2020 Summer Olympics?")
# Out:
# ' Japan National Stadium'

# %% [markdown]
# After we fine-tune the model for Q&A we'll be able to use it instead of [`davinci-instruct-beta-v3`](https://beta.openai.com/docs/engines/instruct-series-beta), to obtain better answers when the question can't be answered based on the context. We see a downside of [`davinci-instruct-beta-v3`](https://beta.openai.com/docs/engines/instruct-series-beta), which always attempts to answer the question, regardless of the relevant context being present or not. (Note the second question is asking about a future event, set in 2024.)

# %%
answer_question(olympics_search_fileid, "davinci-instruct-beta-v3", 
            "Where did women's 4 x 100 metres relay event take place during the 2048 Summer Olympics?", max_len=1000)
# Out:
# ' Japan National Stadium'

# %% [markdown]
# We can see that davinci has a tendency to answer the question, even if the question can't be answered given the context provided. Note the question asked regarding 2048 Summer Olympics, which didn't happen yet, and the retrieved content has only returned results for 2020.

# %% [markdown]
# ## 2.7 (Optional) Investigation into how likely the search endpoint is to return the relevant context

# %%
def check_context(title, heading, question, max_len=1800, search_model='ada', max_rerank=10):
    """
    Evaluate the performance of the search model in retrieving the correct context

    Parameters
    ----------
    title: str
        The title of the Wikipedia page
    heading: str
        The heading of the Wikipedia section
    qusetion: str
        The question
    max_len: int
        The maximum length of the context
    search_model: str
        The search model to use - `ada` is most cost effective
    max_rerank: int
        The maximum number of reranking documents to use the search model on

    Returns
    -------
    rank: int
        The rank of the correct context
    token_length: int
        The number of tokens needed to obtain the correct context
    """
    
    try:
        results = openai.Engine(search_model).search(
            search_model=search_model, 
            query=question, 
            max_rerank=max_rerank,
            file=olympics_search_fileid,
            return_metadata=True
        )
        index=-1
        returns = []
        cur_len = 0
        for result in results['data']:
            cur_len += int(result['metadata']) + 4 # we add 4 tokens for the separator `\n\n###\n\n`
            if cur_len > max_len:
                break
            returns.append(result['text'])
            res = result['text'].split('\n')
            if res[0] == title and res[1] == heading:
                index = len(returns) - 1
                break
        return index, cur_len
    except Exception as e:
        #print (e)
        return []
print(check_context("Athletics at the 2020 Summer Olympics – Women's 4 × 100 metres relay", "Summary", "Where did women's 4 x 100 metres relay event take place during the 2020 Summer Olympics?", max_len=10000))
# Out:
# (0, 58)

# %% [markdown]
# We utilize the generated questions based on context to estimate how often we can retrieve the original context. These questions are noisy, so this is not a perfect estimate.
#
# Our questions and answers are prefixed with numbered bullet points, however due to the way they were generated, they are missing the first number, hence we add "1." to the list of questions (and answers).
#
# We calculate the rank of the section retrieved using ada search, and the number of tokens in the context needed to retrieve the relevant section in full.

# %%
ada_results = df.apply(lambda x: [
                    check_context( x.title, 
                                   x.heading, 
                                   q[3:],     # remove the number prefix
                                   max_len=1000000, # set a large number to get the full context 
                                   search_model='ada', 
                                   max_rerank=200,
                                 ) 
                    for q in (x.questions).split('\n') # split the questions
                    if len(q) >10 # remove the empty questions
                ], axis=1)
ada_results.head()
# Out:
# 0    [(132, 27104), (-1, 22939), (8, 2151), (2, 121...
# 1    [(4, 1737), (0, 130), (8, 744), (96, 17208), (...
# 2          [(0, 373), (0, 373), (-1, 40610), (1, 570)]
# 3            [(0, 302), (0, 302), (5, 968), (8, 1425)]
# 4                      [(0, 167), (0, 167), (2, 1442)]
# Name: ada, dtype: object

# %%
out = pd.concat([ada_results], axis=1)
out.columns = ['ada']
out.to_csv('olympics-data/search_engine_results.csv')

# %%
def expand_lists(out):
    """
    Expand a pandas series containing lists into a series, where each list element becomes a value on its own

    Input is a row per paragraph, which has multiple questions
    Output is a row per question
    """
    cols = [pd.DataFrame(out[name].tolist()).stack().reset_index(level=1, drop=True).rename(name) for name in out.columns] 
    return pd.concat(cols, axis=1)

out_expanded = expand_lists(out)
out_expanded['rank'] = out_expanded.ada.apply(lambda x: x[0] if x != [] else -2)
out_expanded['tokens'] = out_expanded.ada.apply(lambda x: x[1] if x != [] else -2)

# %%
within_2k = (out_expanded.tokens < 2000).mean()
print(f"{within_2k*100:.1f}% of relevant paragraphs are retrieved within the first 2k tokens")
# Out:
# 74.3% of relevant paragraphs are retrieved within the first 2k tokens

# %% [markdown]
# The relevant context can be obtained 74% of the time on this dataset

# %%
outside_200 = (out_expanded['rank'] == -1).mean()
print(f"{outside_200*100:.1f}% of relevant paragraphs are not retrieved within the first 200 results")
# Out:
# 7.4% of relevant paragraphs are not retrieved within the first 200 results

# %% [markdown]
# 7.4% of the time, this is due to the keyword search part of the search algorithm not retrieving the relevant context within the first 200 results.
# 18.3% of the time this is due to the semantic search not placing the relevant context within the first 2000 tokens.

# %%
import matplotlib.pyplot as plt

# plot a histogram, and add axis descriptions and title
out_expanded[(out_expanded['rank'] >=0)&(out_expanded['rank'] <30)]['rank'].hist(bins=29)
plt.xlabel('rank')
plt.ylabel('count')
plt.title('Histogram of ranks of retrieved paragraphs')
plt.show()

# %%
out_expanded[(out_expanded.tokens>=0)&(out_expanded.tokens < 2000)]['tokens'].hist(bins=29)
plt.xlabel('tokens')
plt.ylabel('count')
plt.title('Histogram of the number of minimum tokens needed')
plt.show()

# %% [markdown]
# We can observe that the context is most likely to be returned as one of the first results, and most likely to be returned within the first 200-500 tokens.

# %%
# normalized value_counts
out_expanded['rank'].value_counts(normalize=True).sort_index()[:13]
# Out:
# -2     0.000063
# -1     0.074428
#  0     0.453420
#  1     0.089515
#  2     0.047146
#  3     0.032437
#  4     0.024139
#  5     0.019676
#  6     0.015967
#  7     0.013452
#  8     0.011189
#  9     0.009869
#  10    0.009178
# Name: rank, dtype: float64

# %% [markdown]
# probabilities of the relevant context being returned at each rank. (-2 means a processing error, -1 means the rank is >200)
